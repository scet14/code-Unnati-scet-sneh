# %%
import matplotlib.pyplot as plt

# %%
x=[2,4,6,8]
y=[1,2,3,4]

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y)

# %%
y
# Out:
# [1, 2, 3, 4]

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,linestyle='dotted')

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color= 'r')

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,linestyle='dotted',color= 'r',marker='o')

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color= 'r',marker='o')

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color= 'b',marker='+')

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color= 'b',marker='+', ms=25)

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.bar(x,y,)
# Out:
# <BarContainer object of 4 artists>

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.scatter(x,y,marker='+')
plt.bar(y,x)
# Out:
# <BarContainer object of 4 artists>

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.bar(y,x)
plt.scatter(x,y,marker='+')

# %%
#subplot
import numpy as np
a=np.array([33,44,55,66,77,88])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([9,15,35,42,53,60])

plt.plot(a,b)

# %%
plt.plot(a,c)

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,1)
plt.plot(a,d)

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,1)
plt.plot(a,d)

#plot2
plt.subplot(2,2,2)
plt.plot(a,c)

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,3)
plt.plot(a,d)

#plot2
plt.subplot(2,2,2)
plt.plot(a,c)

# %%
plt.plot(a,d)
#plot1
plt.subplot(3,2,1)
plt.plot(a,d,color='r')

#plot2
plt.subplot(3,2,2)
plt.plot(a,color='y')
#plot3
plt.subplot(3,2,3)
plt.plot(a,b)
#plot4
plt.subplot(3,2,4)
plt.plot(b,d,color='g')

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,3)
plt.plot(a,d)

#plot2
plt.subplot(2,2,4)
plt.plot(a,c)

# %%
#Histogram
data1=np.random.normal(150,10,250)

# %%
data1
# Out:
# array([140.95362991, 164.69431693, 132.81619658, 159.19884227,
#        139.51226145, 153.45102235, 136.40522068, 141.48323703,
#        146.08991073, 147.01964398, 156.38185958, 145.15176466,
#        137.28168787, 151.29563892, 150.27552344, 145.45157039,
#        145.0540077 , 157.99485813, 137.36537458, 148.11290301,
#        133.26350034, 161.50272326, 142.67190001, 144.29767054,
#        142.02748182, 162.52549032, 146.7001052 , 145.40811837,
#        159.14355164, 149.98332813, 165.46612606, 153.40794804,
#        149.17706838, 139.23433986, 151.54910007, 157.67202403,
#        154.12119537, 153.56675482, 150.79737071, 163.48970122,
#        150.0927895 , 146.76613832, 135.78297158, 151.74190865,
#        158.94081347, 169.49826976, 151.78860184, 150.44528274,
#        163.5366219 , 155.69630916, 154.10681755, 148.38288949,
#        162.69880775, 150.13025951, 147.38242126, 143.31233926,
#        146.81996337, 120.55135202, 132.21893787, 147.30515855,
# ...

# %%
len(data1)
# Out:
# 250

# %%
plt.hist(data1,bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=np.array([33,44,55,66,77,88,55])
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#create numpy array for 18 students containg marks of 100 and create histogram with bin size 10

# %%
import numpy as np
data=np.array([65,44,55,66,77,88,48,51,60,72,81,79,91,90,95,85,65,40,])
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#pie chart
#create datasheet
cars=['audi','bmw','tata','honda']
sale=[88,100,89,610,]
#create pie chart
plt.pie(sale,labels=cars)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
